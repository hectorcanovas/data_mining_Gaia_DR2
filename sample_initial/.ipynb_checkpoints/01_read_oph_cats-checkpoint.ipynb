# %% [markdown]
# # 1.- Read OPH catalogues

# %%
import numpy as np
import warnings
import os, glob, getpass, sys

from astropy.table            import Table, join, vstack, hstack, Column, MaskedColumn, unique
from astropy.utils.exceptions import AstropyWarning
from astropy.coordinates      import SkyCoord
from astropy                  import units as u
from astroquery.vizier        import Vizier

user = getpass.getuser()
sys.path.append('../')
from extra_codes import sample_initial as samp_ini

cat_inp = "II/246" # All Catalogue searches in this NoteBook are done agains VizieR/2MASS
cat_rad = 1.0 * u.arcsecond

# %% [markdown]
# ### READ WILKING 2008 CATALOGUE

# %%
# =============================================
# NOTE: CATALOGUE DIRECTLY AVAILABLE ON SIMBAD
# =============================================
warnings.filterwarnings('ignore', category=AstropyWarning, append=True)

cat_wilking = Table.read('2008_wilking_simbad.xml', format = 'votable')
cat_wilking = cat_wilking['MAIN_ID', 'RA_d', 'DEC_d']

print(f'Total Objects in catalogue: {len(cat_wilking):>15.0f}')
cat_wilking['MAIN_ID'] = [inp.decode('utf-8') for inp in cat_wilking['MAIN_ID']]

# ID CrossMatch against 2MASS ==========================
cat_wilking_tmasss = samp_ini.query_ids_1(cat_wilking['MAIN_ID'], catalog = cat_inp, radius = cat_rad)
cat_wilking_tmasss.write('2008_wilking_simbad_2mass.vot', format = 'votable', overwrite = True)
# Out:
# Total Objects in catalogue:             314
# Querying Vizier, ID:  2MASS J16245652-2459381
# Querying Vizier, ID:  2MASS J16245729-2411240
# Querying Vizier, ID:  2MASS J16250792-2431572
# Querying Vizier, ID:  2MASS J16251503-2455440
# Querying Vizier, ID:  CD-24 12683
# Querying Vizier, ID:  2MASS J16252243-2402056
# Querying Vizier, ID:  2MASS J16252401-2356564
# Querying Vizier, ID:  2MASS J16252428-2415401
# Querying Vizier, ID:  HD 147889
# Querying Vizier, ID:  EM* SR   22
# Querying Vizier, ID:  2MASS J16252434-2355103
# Querying Vizier, ID:  EM* SR    8
# Querying Vizier, ID:  2MASS J16253673-2415424
# Querying Vizier, ID:  2MASS J16253812-2422362
# Querying Vizier, ID:  2MASS J16253958-2426349
# Querying Vizier, ID:  2MASS J16254129-2421366
# Querying Vizier, ID:  2MASS J16254767-2437394
# Querying Vizier, ID:  ROX  3
# Querying Vizier, ID:  2MASS J16255052-2439145
# Querying Vizier, ID:  EM* SR    5
# Querying Vizier, ID:  2MASS J16255609-2430148
# Querying Vizier, ID:  EM* SR    4
# Querying Vizier, ID:  2MASS J16255752-2430317
# Querying Vizier, ID:  2MASS J16255893-2452483
# Querying Vizier, ID:  2MASS J16255965-2421223
# Querying Vizier, ID:  2MASS J16260137-2425203
# Querying Vizier, ID:  2MASS J16260160-2429449
# Querying Vizier, ID:  Haro 1-6
# Querying Vizier, ID:  2MASS J16260329-2417464
# Querying Vizier, ID:  2MASS J16260457-2417514
# Querying Vizier, ID:  2MASS J16260544-2355408
# Querying Vizier, ID:  2MASS J16260704-2427241
# Querying Vizier, ID:  2MASS J16260714-2435129
# Querying Vizier, ID:  2MASS J16260763-2427413
# Querying Vizier, ID:  EM* SR    3
# Querying Vizier, ID:  2MASS J16260993-2433540
# Querying Vizier, ID:  GSS 26
# Querying Vizier, ID:  CRBR 2314.4-1237
# Querying Vizier, ID:  2MASS J16261632-2439306
# Querying Vizier, ID:  2MASS J16261684-2422231
# Querying Vizier, ID:  DoAr 24
# Querying Vizier, ID:  2MASSI J1626172-241238
# Querying Vizier, ID:  2MASS J16261722-2423453
# Querying Vizier, ID:  2MASS J16261813-2430330
# Querying Vizier, ID:  2MASS J16261847-2407112
# Querying Vizier, ID:  2MASS J16261858-2429514
# Querying Vizier, ID:  2MASS J16261877-2407190
# Querying Vizier, ID:  ISO-Oph  23
# Querying Vizier, ID:  YLW 31
# Querying Vizier, ID:  CRBR 2317.5-1729
# Querying Vizier, ID:  2MASS J16261949-2437275
# Querying Vizier, ID:  2MASS J16262083-2428395
# Querying Vizier, ID:  2MASS J16262097-2408518
# Querying Vizier, ID:  2MASS J16262138-2423040
# Querying Vizier, ID:  ISO-Oph  30
# Querying Vizier, ID:  [CHG85] GSS 30 IRS 3
# Querying Vizier, ID:  ISO-Oph  32
# Querying Vizier, ID:  2MASS J16262203-2442364
# Querying Vizier, ID:  2MASS J16262218-2423523
# Querying Vizier, ID:  ISO-Oph  33
# Querying Vizier, ID:  2MASS J16262238-2422529
# Querying Vizier, ID:  2MASS J16262295-2428461
# Querying Vizier, ID:  GSS 31
# Querying Vizier, ID:  ISO-Oph  37
# Querying Vizier, ID:  DoAr 25
# Querying Vizier, ID:  2MASS J16262381-2418290
# Querying Vizier, ID:  GSS 32
# Querying Vizier, ID:  2MASS J16262407-2416134
# Querying Vizier, ID:  2MASS J16262425-2401156
# Querying Vizier, ID:  2MASS J16262523-2423239
# Querying Vizier, ID:  2MASS J16262528-2424450
# Querying Vizier, ID:  [GY92]  30
# Querying Vizier, ID:  2MASS J16262568-2414278
# Querying Vizier, ID:  2MASS J16262753-2441535
# Querying Vizier, ID:  2MASS J16262780-2426418
# Querying Vizier, ID:  2MASS J16262847-2415411
# Querying Vizier, ID:  2MASS J16262967-2419055
# Querying Vizier, ID:  2MASS J16263046-2422571
# Querying Vizier, ID:  2MASS J16263103-2431052
# Querying Vizier, ID:  2MASS J16263135-2425302
# Querying Vizier, ID:  2MASS J16263252-2426354
# Querying Vizier, ID:  2MASS J16263297-2400168
# Querying Vizier, ID:  2MASS J16263416-2423282
# Querying Vizier, ID:  V* V2675 Oph
# Querying Vizier, ID:  2MASS J16263682-2415518
# Querying Vizier, ID:  2MASSI J1626371-241559
# Querying Vizier, ID:  2MASS J16263778-2423007
# Querying Vizier, ID:  2MASS J16263780-2439031
# Querying Vizier, ID:  2MASS J16263880-2423227
# Querying Vizier, ID:  2MASS J16263991-2422334
# Querying Vizier, ID:  2MASS J16264046-2427144
# Querying Vizier, ID:  2MASS J16264083-2430509
# Querying Vizier, ID:  [GY92]  93
# Querying Vizier, ID:  2MASS J16264201-2433262
# Querying Vizier, ID:  2MASS J16264214-2431029
# Querying Vizier, ID:  2MASS J16264243-2426258
# Querying Vizier, ID:  2MASS J16264252-2426319
# Querying Vizier, ID:  2MASS J16264273-2424277
# Querying Vizier, ID:  2MASS J16264285-2420299
# Querying Vizier, ID:  2MASS J16264289-2422590
# Querying Vizier, ID:  2MASS J16264310-2411095
# Querying Vizier, ID:  2MASS J16264375-2416333
# Querying Vizier, ID:  2MASS J16264386-2424506
# Querying Vizier, ID:  2MASS J16264419-2434483
# Querying Vizier, ID:  2MASS J16264429-2443141
# Querying Vizier, ID:  2MASS J16264441-2447138
# Querying Vizier, ID:  2MASS J16264502-2423077
# Querying Vizier, ID:  2MASS J16264612-2358101
# Querying Vizier, ID:  2MASS J16264643-2412000
# Querying Vizier, ID:  2MASS J16264675-2419083
# Querying Vizier, ID:  2MASS J16264705-2444298
# Querying Vizier, ID:  2MASS J16264810-2442033
# Querying Vizier, ID:  2MASS J16264839-2428348
# Querying Vizier, ID:  2MASS J16264848-2428389
# Querying Vizier, ID:  2MASS J16264853-2412273
# Querying Vizier, ID:  2MASS J16264864-2356341
# Querying Vizier, ID:  WL 18
# Querying Vizier, ID:  2MASS J16264923-2420029
# Querying Vizier, ID:  2MASS J16265048-2413522
# Querying Vizier, ID:  2MASS J16265128-2432419
# Querying Vizier, ID:  2MASS J16265168-2414415
# Querying Vizier, ID:  2MASS J16265197-2430394
# Querying Vizier, ID:  2MASS J16265335-2440023
# Querying Vizier, ID:  2MASS J16265346-2432362
# Querying Vizier, ID:  2MASS J16265429-2424381
# Querying Vizier, ID:  2MASS J16265444-2426207
# Querying Vizier, ID:  2MASS J16265477-2427022
# Querying Vizier, ID:  2MASS J16265497-2422296
# Querying Vizier, ID:  2MASS J16265636-2441204
# Querying Vizier, ID:  2MASS J16265677-2413515
# Querying Vizier, ID:  2MASS J16265733-2435388
# Querying Vizier, ID:  EM* SR   23
# Querying Vizier, ID:  2MASS J16265827-2437409
# Querying Vizier, ID:  2MASS J16265839-2421299
# Querying Vizier, ID:  EM* SR   24B
# Querying Vizier, ID:  EM* SR   24A
# Querying Vizier, ID:  ISO-Oph  87
# Querying Vizier, ID:  2MASS J16265867-2424555
# Querying Vizier, ID:  2MASS J16265904-2435568
# Querying Vizier, ID:  2MASS J16265916-2434588
# Querying Vizier, ID:  2MASS J16265950-2419508
# Querying Vizier, ID:  2MASS J16270055-2416255
# Querying Vizier, ID:  YLW  5
# Querying Vizier, ID:  2MASS J16270300-2426146
# Querying Vizier, ID:  ISO-Oph  94
# Querying Vizier, ID:  2MASS J16270405-2409318
# Querying Vizier, ID:  2MASS J16270410-2428299
# Querying Vizier, ID:  2MASS J16270451-2442596
# Querying Vizier, ID:  2MASS J16270456-2442140
# Querying Vizier, ID:  2MASS J16270457-2427156
# Querying Vizier, ID:  2MASS J16270516-2420077
# Querying Vizier, ID:  2MASS J16270524-2436297
# Querying Vizier, ID:  2MASS J16270567-2440130
# Querying Vizier, ID:  2MASS J16270592-2418402
# Querying Vizier, ID:  2MASS J16270597-2428363
# Querying Vizier, ID:  2MASS J16270597-2426185
# Querying Vizier, ID:  2MASS J16270604-2438123
# Querying Vizier, ID:  2MASS J16270650-2419214
# Querying Vizier, ID:  2MASS J16270655-2407031
# Querying Vizier, ID:  ISO-Oph 102
# Querying Vizier, ID:  2MASS J16270677-2438149
# Querying Vizier, ID:  2MASS J16270750-2441040
# Querying Vizier, ID:  2MASS J16270907-2412007
# Querying Vizier, ID:  BBRCG 24
# Querying Vizier, ID:  2MASS J16270931-2443196
# Querying Vizier, ID:  2MASS J16270935-2440224
# Querying Vizier, ID:  2MASS J16270943-2437187
# Querying Vizier, ID:  2MASS J16271003-2429133
# Querying Vizier, ID:  EM* SR   21A
# Querying Vizier, ID:  2MASS J16271030-2410295
# Querying Vizier, ID:  2MASS J16271031-2419188
# Querying Vizier, ID:  2MASS J16271117-2440466
# Querying Vizier, ID:  2MASS J16271171-2438320
# Querying Vizier, ID:  2MASS J16271187-2410312
# Querying Vizier, ID:  WL 11
# Querying Vizier, ID:  2MASS J16271372-2418168
# Querying Vizier, ID:  [GY92] 235
# Querying Vizier, ID:  2MASS J16271448-2451334
# Querying Vizier, ID:  2MASS J16271450-2426460
# Querying Vizier, ID:  2MASS J16271513-2451388
# Querying Vizier, ID:  [GY92] 239
# Querying Vizier, ID:  2MASS J16271551-2430536
# Querying Vizier, ID:  2MASS J16271569-2438434
# Querying Vizier, ID:  NAME WL 20E
# Querying Vizier, ID:  2MASS J16271588-2425141
# Querying Vizier, ID:  2MASS J16271643-2431145
# Querying Vizier, ID:  2MASS J16271707-2447111
# Querying Vizier, ID:  2MASS J16271757-2428562
# Querying Vizier, ID:  ISO-Oph 123
# Querying Vizier, ID:  2MASS J16271817-2428526
# Querying Vizier, ID:  2MASS J16271836-2454537
# Querying Vizier, ID:  2MASS J16271838-2439146
# Querying Vizier, ID:  SSTc2d J162718.4-242905
# Querying Vizier, ID:  2MASS J16271921-2428438
# Querying Vizier, ID:  EM* SR   12
# Querying Vizier, ID:  2MASS J16272146-2441430
# Querying Vizier, ID:  YLW 14
# Querying Vizier, ID:  2MASS J16272183-2443356
# Querying Vizier, ID:  2MASS J16272183-2427275
# Querying Vizier, ID:  2MASS J16272197-2429397
# Querying Vizier, ID:  2MASS J16272291-2417573
# Querying Vizier, ID:  WSB 49
# Querying Vizier, ID:  2MASS J16272419-2429294
# Querying Vizier, ID:  2MASS J16272439-2441475
# Querying Vizier, ID:  2MASS J16272461-2441034
# Querying Vizier, ID:  2MASS J16272463-2429353
# Querying Vizier, ID:  2MASS J16272622-2419229
# Querying Vizier, ID:  2MASS J16272628-2442461
# Querying Vizier, ID:  [GY92] 262
# Querying Vizier, ID:  2MASS J16272658-2425543
# Querying Vizier, ID:  2MASS J16272661-2440451
# Querying Vizier, ID:  2MASS J16272693-2440508
# Querying Vizier, ID:  2MASS J16272706-2432175
# Querying Vizier, ID:  2MASS J16272738-2431165
# Querying Vizier, ID:  [GY92] 269
# Querying Vizier, ID:  2MASS J16272844-2427210
# Querying Vizier, ID:  2MASS J16272873-2454317
# Querying Vizier, ID:  [GY92] 274
# Querying Vizier, ID:  2MASS J16272996-2433365
# Querying Vizier, ID:  2MASS J16273018-2427433
# Querying Vizier, ID:  2MASS J16273045-2435353
# Querying Vizier, ID:  2MASS J16273052-2432347
# Querying Vizier, ID:  2MASS J16273084-2447268
# Querying Vizier, ID:  2MASS J16273084-2424560
# Querying Vizier, ID:  2MASS J16273091-2427331
# Querying Vizier, ID:  2MASS J16273105-2434032
# Querying Vizier, ID:  2MASS J16273213-2429435
# Querying Vizier, ID:  2MASS J16273267-2433239
# Querying Vizier, ID:  2MASS J16273271-2432423
# Querying Vizier, ID:  2MASS J16273272-2445004
# Querying Vizier, ID:  2MASS J16273285-2432348
# Querying Vizier, ID:  2MASS J16273311-2441152
# Querying Vizier, ID:  2MASS J16273526-2438334
# Querying Vizier, ID:  2MASS J16273566-2445325
# Querying Vizier, ID:  2MASS J16273704-2421440
# Querying Vizier, ID:  2MASS J16273714-2359330
# Querying Vizier, ID:  IRAS 16245-2423
# Querying Vizier, ID:  2MASS J16273724-2442380
# Querying Vizier, ID:  ISO-Oph 160
# Querying Vizier, ID:  2MASS J16273797-2357238
# Querying Vizier, ID:  2MASS J16273812-2430429
# Querying Vizier, ID:  YLW 47
# Querying Vizier, ID:  Haro 1-11
# Querying Vizier, ID:  2MASS J16273833-2404013
# Querying Vizier, ID:  [GY92] 310
# Querying Vizier, ID:  [GY92] 312
# Querying Vizier, ID:  DoAr 33
# Querying Vizier, ID:  2MASS J16273914-2421503
# Querying Vizier, ID:  2MASS J16273942-2439155
# Querying Vizier, ID:  2MASS J16273971-2422476
# Querying Vizier, ID:  2MASS J16273982-2443150
# Querying Vizier, ID:  2MASS J16274010-2426365
# Querying Vizier, ID:  EM* SR    9
# Querying Vizier, ID:  2MASS J16274055-2424496
# Querying Vizier, ID:  2MASS J16274084-2429007
# Querying Vizier, ID:  2MASS J16274145-2436571
# Querying Vizier, ID:  2MASS J16274149-2435376
# Querying Vizier, ID:  2MASS J16274160-2438382
# Querying Vizier, ID:  2MASS J16274161-2446447
# Querying Vizier, ID:  2MASS J16274175-2443360
# Querying Vizier, ID:  2MASS J16274178-2442346
# Querying Vizier, ID:  2MASS J16274187-2404272
# Querying Vizier, ID:  2MASS J16274225-2422261
# Querying Vizier, ID:  2MASS J16274270-2438506
# Querying Vizier, ID:  2MASS J16274522-2503328
# Querying Vizier, ID:  [GY92] 344
# Querying Vizier, ID:  [GY92] 350
# Querying Vizier, ID:  2MASS J16274709-2445350
# Querying Vizier, ID:  2MASS J16274799-2457134
# Querying Vizier, ID:  2MASS J16274978-2425219
# Querying Vizier, ID:  2MASS J16274987-2425402
# Querying Vizier, ID:  2MASS J16275113-2425321
# Querying Vizier, ID:  YLW 52
# Querying Vizier, ID:  2MASS J16275191-2446296
# Querying Vizier, ID:  2MASS J16275209-2440503
# Querying Vizier, ID:  2MASS J16275485-2422595
# Querying Vizier, ID:  2MASS J16275525-2428395
# Querying Vizier, ID:  EM* SR   10
# Querying Vizier, ID:  2MASS J16275565-2444509
# Querying Vizier, ID:  2MASS J16275782-2440017
# Querying Vizier, ID:  2MASS J16275996-2448193
# Querying Vizier, ID:  2MASS J16280011-2453427
# Querying Vizier, ID:  2MASS J16280080-2400517
# Querying Vizier, ID:  2MASS J16280355-2434386
# Querying Vizier, ID:  2MASS J16280464-2434560
# Querying Vizier, ID:  2MASS J16280478-2437100
# Querying Vizier, ID:  2MASS J16280478-2450354
# Querying Vizier, ID:  2MASS J16280810-2445121
# Querying Vizier, ID:  2MASS J16281099-2406177
# Querying Vizier, ID:  2MASS J16281254-2450453
# Querying Vizier, ID:  ISO-Oph 193
# Querying Vizier, ID:  2MASS J16281370-2431391
# Querying Vizier, ID:  2MASS J16281379-2432494
# Querying Vizier, ID:  YLW 58
# Querying Vizier, ID:  2MASS J16281673-2405142
# Querying Vizier, ID:  2MASS J16281922-2457340
# Querying Vizier, ID:  2MASS J16282004-2423178
# Querying Vizier, ID:  2MASS J16282151-2421549
# Querying Vizier, ID:  2MASS J16282157-2455328
# Querying Vizier, ID:  2MASS J16282170-2442471
# Querying Vizier, ID:  NAME EM* SR 20W
# Querying Vizier, ID:  2MASS J16282373-2441412
# Querying Vizier, ID:  2MASS J16282430-2409316
# Querying Vizier, ID:  2MASS J16282479-2435434
# Querying Vizier, ID:  HD 148352
# Querying Vizier, ID:  2MASS J16283256-2415242
# Querying Vizier, ID:  EM* SR   20
# Querying Vizier, ID:  2MASS J16284304-2422522
# Querying Vizier, ID:  EM* SR   13
# Querying Vizier, ID:  2MASS J16284999-2435181
# Querying Vizier, ID:  2MASS J16285084-2457145
# Querying Vizier, ID:  2MASS J16285407-2447442
# Querying Vizier, ID:  2MASS J16285694-2431096
# Querying Vizier, ID:  2MASS J16290392-2451414

# %%
# Check output catalogue ===============================
samp_ini.check_2mass(cat_wilking, cat_wilking_tmasss)
cat_wilking_tmasss[0:3]
# Out:
# Input Targets in 2MASS Catalogue:        314
# Missing 2MASS targets:                     0
# <Table masked=True length=3>
#  RAJ2000    DEJ2000        _2MASS      ...    _r   dummy          inp_id
#    deg        deg                      ...  arcsec
#  float64    float64       bytes17      ... float64  str1          str23
# ---------- ---------- ---------------- ... ------- ----- -----------------------
# 246.235514 -24.993937 16245652-2459381 ...    0.10     N 2MASS J16245652-2459381
# 246.238721 -24.190016 16245729-2411240 ...    0.25     N 2MASS J16245729-2411240
# 246.283034 -24.532566 16250792-2431572 ...    0.22     N 2MASS J16250792-2431572

# %% [markdown]
# ### READ ERICKSON 2011 CATALOGUE

# %%
# Read Erickson+2011 OPH catalogues ====================
warnings.simplefilter('ignore', category=AstropyWarning)
tab_2005   = Table.read('2005_wilking_Table2.vot',  format = 'votable') #219 Targets - Coords.
tab_2011_2 = Table.read('2011_erickson_Table2.vot', format = 'votable') #219 Targets - Coords.
tab_2011_3 = Table.read('2011_erickson_Table3.vot', format = 'votable') #135 Confirmed members - No-Coords

#Column SubSet ===
tab_2005   = tab_2005['Seq',  'RAJ2000', 'DEJ2000', 'Names']
tab_2011_2 = tab_2011_2['ID', 'RAJ2000', 'DEJ2000']
tab_2011_3 = tab_2011_3['ID', 'Name', 'Source'] # Source == Seq on Wilking+2005

tab_2005.convert_bytestring_to_unicode()
tab_2005['Source'] = [inp.replace(' ','') for inp in tab_2005['Seq']] # For later match

tab_2011_2.convert_bytestring_to_unicode()
tab_2011_3.convert_bytestring_to_unicode()

# %%
# Targets with SIMBAD ID ===============================
cat_erickson_1 = tab_2011_3[tab_2011_3['Name'] != '']
print('{:31s}{:>4.0f}'.format('Total Objects in Erickson+2011 group 1:', len(cat_erickson_1)))

for i in range(len(cat_erickson_1)):
    name = cat_erickson_1['Name'][i]
    if name[0:2] == 'SR':  name = name.replace('SR','EM* SR')
    if name[0:2] == 'GY':  name = name.replace('GY','GY92')
    if '/' in name:        name = name[0:name.find('/')]


    #Individual Cases ====
    if 'ROXR1-4' in name:  name = 'EM* SR 8'
    if name == 'VSS 23':   name = 'VSS II-23'
    if name == 'Chini 8':  name = '[C81] 8'
    if name == 'EL 24':    name = 'Elia 2-24'
    if name == 'Source 1': name = 'Elia 2-25' # See Comments on Vizier/Paper Table
    if name == 'ROX 30A':  name = 'ROXs 30A'  # See Comments on Vizier/Paper Table
    if name == 'ROX 35A':  name = 'ROXs 35A'  # See Comments on Vizier/Paper Table
    if name == 'ROX 35B':  name = 'ROXs 35B'  # See Comments on Vizier/Paper Table
            
    cat_erickson_1['Name'][i] = name


# ID CrossMatch against 2MASS ==========================
cat_erickson_1_tmasss = samp_ini.query_ids_1(cat_erickson_1['Name'], catalog = cat_inp, radius = cat_rad)
cat_erickson_1_tmasss.write('cat_erickson_1_tmasss.vot', format = 'votable', overwrite = True)
# Out:
# Total Objects in Erickson+2011 group 1:  74
# Querying Vizier, ID:  RXJ 1624.9-2459
# Querying Vizier, ID:  WSB 18
# Querying Vizier, ID:  WSB 19
# Querying Vizier, ID:  GSS 5
# Querying Vizier, ID:  EM* SR 22
# Querying Vizier, ID:  HD 147889
# Querying Vizier, ID:  EM* SR 8
# Querying Vizier, ID:  WLY 2-2
# Querying Vizier, ID:  WLY 2-3
# Querying Vizier, ID:  ROX 3
# Querying Vizier, ID:  VSS II-23
# Querying Vizier, ID:  WLY 2-11
# Querying Vizier, ID:  EM* SR 4
# Querying Vizier, ID:  GSS 20
# Querying Vizier, ID:  [C81] 8
# Querying Vizier, ID:  GSS 23
# Querying Vizier, ID:  VSSG 19
# Querying Vizier, ID:  EM* SR 3
# Querying Vizier, ID:  GSS 29
# Querying Vizier, ID:  GSS 28
# Querying Vizier, ID:  WSB 28
# Querying Vizier, ID:  GY92 5
# Querying Vizier, ID:  GY92 3
# Querying Vizier, ID:  GSS 31
# Querying Vizier, ID:  DoAr 25
# Querying Vizier, ID:  Elia 2-24
# Querying Vizier, ID:  GSS 32
# Querying Vizier, ID:  WSB 34
# Querying Vizier, ID:  Elia 2-25
# Querying Vizier, ID:  ISO-Oph 51
# Querying Vizier, ID:  WSB 37
# Querying Vizier, ID:  GSS 37
# Querying Vizier, ID:  GY92 112
# Querying Vizier, ID:  WSB 38
# Querying Vizier, ID:  WSB 40
# Querying Vizier, ID:  WL 18
# Querying Vizier, ID:  EM* SR 24s
# Querying Vizier, ID:  EM* SR 24n
# Querying Vizier, ID:  GY92 194
# Querying Vizier, ID:  GY92 204
# Querying Vizier, ID:  ISO-Oph 106
# Querying Vizier, ID:  EM* SR 21
# Querying Vizier, ID:  WSB 45
# Querying Vizier, ID:  WSB 46
# Querying Vizier, ID:  WSB 48
# Querying Vizier, ID:  EM* SR 12
# Querying Vizier, ID:  WSB 49
# Querying Vizier, ID:  GY92 264
# Querying Vizier, ID:  GY92 280
# Querying Vizier, ID:  GY92 284
# Querying Vizier, ID:  GY92 292
# Querying Vizier, ID:  WSB 50
# Querying Vizier, ID:  ROXs 30A
# Querying Vizier, ID:  WLY 2-48
# Querying Vizier, ID:  WLY 2-49
# Querying Vizier, ID:  WSB 51
# Querying Vizier, ID:  WSB 53
# Querying Vizier, ID:  WSB 52
# Querying Vizier, ID:  EM* SR 9
# Querying Vizier, ID:  GY92 326
# Querying Vizier, ID:  VSSG 14
# Querying Vizier, ID:  ROX 31
# Querying Vizier, ID:  EM* SR 10
# Querying Vizier, ID:  WSB 58
# Querying Vizier, ID:  ROX 32
# Querying Vizier, ID:  ISO-Oph 194
# Querying Vizier, ID:  WSB 60
# Querying Vizier, ID:  ISO-Oph 195
# Querying Vizier, ID:  HD 148352
# Querying Vizier, ID:  EM* SR 20
# Querying Vizier, ID:  EM* SR 13
# Querying Vizier, ID:  WSB 63
# Querying Vizier, ID:  ROXs 35A
# Querying Vizier, ID:  ROXs 35B

# %%
# Check output catalogue ===============================
samp_ini.check_2mass(cat_erickson_1, cat_erickson_1_tmasss)
cat_erickson_1_tmasss[0:3]
# Out:
# Input Targets in 2MASS Catalogue:         74
# Missing 2MASS targets:                     1
# <Table masked=True length=3>
#  RAJ2000    DEJ2000        _2MASS        Jmag  ...  Aflg    _r   dummy   inp_id
#    deg        deg                        mag   ...        arcsec
#  float64    float64       bytes17      float32 ... uint8 float64  str1   str15
# ---------- ---------- ---------------- ------- ... ----- ------- ----- ---------
# 246.598657 -24.720518 16262367-2443138   9.391 ...     0    0.19     N   DoAr 25
# 246.981587 -24.438307 16275558-2426179  10.143 ...     0    0.13     N EM* SR 10
# 246.831300 -24.694553 16271951-2441403   9.424 ...     0    0.09     N EM* SR 12

# %%
# Targets w/o SIMBAD ID ================================
sub_tab        = tab_2011_3[tab_2011_3['Name'] == '']


# COORDS IN ID @ Table2 ERICKSON_2011 ======
cat_erickson_2 = sub_tab[sub_tab['ID'] != '']
cat_erickson_2 = join(cat_erickson_2, tab_2011_2, keys='ID')
cat_erickson_2 = cat_erickson_2.group_by('RAJ2000')
print('Erickson+2011 group 2 N_targets: ',len(cat_erickson_2))


# COORDS IN ID @ WILKING_2005 ==============
cat_erickson_3 = sub_tab[sub_tab['ID'] == '']
cat_erickson_3 = join(cat_erickson_3, tab_2005, keys='Source')
cat_erickson_3 = cat_erickson_3.group_by('RAJ2000')
print('Erickson+2011 group 3 N_targets: ',len(cat_erickson_3))


# Write Erickson Catalogues for later inspection
cat_erickson_1.write('cat_erickson_1.vot', format = 'votable', overwrite = True)
cat_erickson_2.write('cat_erickson_2.vot', format = 'votable', overwrite = True)
cat_erickson_3.write('cat_erickson_3.vot', format = 'votable', overwrite = True)
# Out:
# Erickson+2011 group 2 N_targets:  44
# Erickson+2011 group 3 N_targets:  17

# %%
# Coordinate CrossMatch against 2MASS ==================
inp_coords            = SkyCoord(cat_erickson_2['RAJ2000'],cat_erickson_2['DEJ2000'], unit = (u.hourangle, u.deg))
cat_erickson_2_tmasss = samp_ini.query_coords(inp_coords, catalog = cat_inp, radius=3.5*u.arcsecond) # Note the large radii (Catalogue coords errors)

# %%
# Check output catalogue ===============================
cat_erickson_2_tmasss.write('cat_erickson_2_tmasss.vot', format = 'votable', overwrite = True)
samp_ini.check_2mass(cat_erickson_2, cat_erickson_2_tmasss)
# Out:
# Input Targets in 2MASS Catalogue:         44
# Missing 2MASS targets:                     0

# %%
# Coordinate CrossMatch against 2MASS ==================
inp_coords            = SkyCoord(cat_erickson_3['RAJ2000'],cat_erickson_3['DEJ2000'], unit = (u.hourangle, u.deg))
cat_erickson_3_tmasss = samp_ini.query_coords(inp_coords, catalog = cat_inp, radius=1.5*u.arcsecond)

cat_erickson_3_tmasss.write('cat_erickson_3_tmasss.vot', format = 'votable', overwrite = True)
samp_ini.check_2mass(cat_erickson_3, cat_erickson_3_tmasss)
# Out:
# Input Targets in 2MASS Catalogue:         17
# Missing 2MASS targets:                     0

# %% [markdown]
# ### READ C2D 2015 Dunham OPH/YSO CATALOGUE

# %%
# Read Dunham 2015 =====================================
cat_dunham = Table.read('2015_dunham_OPH_YSO.vot')
cat_dunham.convert_bytestring_to_unicode()

# ID CrossMatch against 2MASS ==========================
cat_dunham_tmasss = samp_ini.query_ids_1(cat_dunham['SimbadName'], catalog=cat_inp, verbose = True)
cat_dunham_tmasss.write('2015_dunham_OPH_YSO_tmasss.vot', format = 'votable', overwrite = True)
samp_ini.check_2mass(cat_dunham, cat_dunham_tmasss)
# Out:
# Querying Vizier, ID:  SSTc2d J162110.9-234328
# Querying Vizier, ID:  SSTc2d J162118.4-225457
# Querying Vizier, ID:  SSTc2d J162119.1-234228
# Querying Vizier, ID:  SSTc2d J162131.9-230140
# Querying Vizier, ID:  SSTc2d J162138.7-225328
# Querying Vizier, ID:  SSTc2d J162141.9-231343
# Querying Vizier, ID:  SSTc2d J162145.1-234231
# Querying Vizier, ID:  SSTc2d J162148.4-234027
# Querying Vizier, ID:  SSTc2d J162157.6-242943
# Querying Vizier, ID:  SSTc2d J162218.5-232148
# Querying Vizier, ID:  SSTc2d J162220.9-230402
# Querying Vizier, ID:  SSTc2d J162224.4-245018
# Querying Vizier, ID:  SSTc2d J162224.9-232954
# Querying Vizier, ID:  SSTc2d J162235.6-233734
# Querying Vizier, ID:  SSTc2d J162241.7-242538
# Querying Vizier, ID:  SSTc2d J162244.9-231713
# Querying Vizier, ID:  SSTc2d J162245.3-243123
# Querying Vizier, ID:  SSTc2d J162247.1-230013
# Querying Vizier, ID:  SSTc2d J162248.6-230217
# Querying Vizier, ID:  SSTc2d J162259.8-232635
# Querying Vizier, ID:  SSTc2d J162305.4-230256
# Querying Vizier, ID:  SSTc2d J162305.8-233817
# Querying Vizier, ID:  SSTc2d J162306.8-225736
# Querying Vizier, ID:  SSTc2d J162308.7-225742
# Querying Vizier, ID:  SSTc2d J162309.2-241704
# Querying Vizier, ID:  SSTc2d J162312.5-243641
# Querying Vizier, ID:  SSTc2d J162313.6-230358
# Querying Vizier, ID:  SSTc2d J162315.6-234300
# Querying Vizier, ID:  SSTc2d J162332.2-242553
# Querying Vizier, ID:  SSTc2d J162332.8-225846
# Querying Vizier, ID:  SSTc2d J162334.6-230846
# Querying Vizier, ID:  SSTc2d J162334.8-234030
# Querying Vizier, ID:  SSTc2d J162336.1-240220
# Querying Vizier, ID:  SSTc2d J162338.5-230544
# Querying Vizier, ID:  SSTc2d J162340.0-233337
# Querying Vizier, ID:  SSTc2d J162350.5-225838
# Querying Vizier, ID:  SSTc2d J162355.5-234210
# Querying Vizier, ID:  SSTc2d J162413.4-241822
# Querying Vizier, ID:  SSTc2d J162415.9-241114
# Querying Vizier, ID:  SSTc2d J162435.1-242619
# Querying Vizier, ID:  SSTc2d J162452.3-250127
# Querying Vizier, ID:  SSTc2d J162453.0-250556
# Querying Vizier, ID:  SSTc2d J162459.7-245600
# Querying Vizier, ID:  SSTc2d J162502.0-245932
# Querying Vizier, ID:  SSTc2d J162506.2-244657
# Querying Vizier, ID:  SSTc2d J162506.9-235050
# Querying Vizier, ID:  SSTc2d J162522.1-241750
# Querying Vizier, ID:  SSTc2d J162522.5-243453
# Querying Vizier, ID:  SSTc2d J162524.3-242944
# Querying Vizier, ID:  SSTc2d J162527.5-243647
# Querying Vizier, ID:  SSTc2d J162532.1-235402
# Querying Vizier, ID:  SSTc2d J162532.5-232626
# Querying Vizier, ID:  SSTc2d J162533.1-232530
# Querying Vizier, ID:  SSTc2d J162535.4-243210
# Querying Vizier, ID:  SSTc2d J162536.7-241542
# Querying Vizier, ID:  SSTc2d J162538.1-242236
# Querying Vizier, ID:  SSTc2d J162539.4-232641
# Querying Vizier, ID:  SSTc2d J162539.5-242634
# Querying Vizier, ID:  SSTc2d J162542.8-232526
# Querying Vizier, ID:  SSTc2d J162546.6-242336
# Querying Vizier, ID:  SSTc2d J162556.1-242048
# Querying Vizier, ID:  SSTc2d J162601.3-242520
# Querying Vizier, ID:  SSTc2d J162603.0-242336
# Querying Vizier, ID:  SSTc2d J162604.5-241751
# Querying Vizier, ID:  SSTc2d J162605.7-244255
# Querying Vizier, ID:  SSTc2d J162607.0-242724
# Querying Vizier, ID:  SSTc2d J162610.3-242054
# Querying Vizier, ID:  SSTc2d J162614.6-242507
# Querying Vizier, ID:  SSTc2d J162616.8-242222
# Querying Vizier, ID:  SSTc2d J162617.0-242021
# Querying Vizier, ID:  SSTc2d J162617.2-242345
# Querying Vizier, ID:  SSTc2d J162618.1-243033
# Querying Vizier, ID:  SSTc2d J162618.8-242610
# Querying Vizier, ID:  SSTc2d J162618.8-242819
# Querying Vizier, ID:  SSTc2d J162618.9-242414
# Querying Vizier, ID:  SSTc2d J162619.4-243727
# Querying Vizier, ID:  SSTc2d J162620.8-242839
# Querying Vizier, ID:  SSTc2d J162620.9-240846
# Querying Vizier, ID:  SSTc2d J162621.3-242304
# Querying Vizier, ID:  SSTc2d J162621.5-242600
# Querying Vizier, ID:  SSTc2d J162621.8-244439
# Querying Vizier, ID:  SSTc2d J162622.2-242407
# Querying Vizier, ID:  SSTc2d J162622.9-242846
# Querying Vizier, ID:  SSTc2d J162623.4-242100
# Querying Vizier, ID:  SSTc2d J162623.5-242439
# Querying Vizier, ID:  SSTc2d J162623.6-244314
# Querying Vizier, ID:  SSTc2d J162623.8-241829
# Querying Vizier, ID:  SSTc2d J162624.0-242448
# Querying Vizier, ID:  SSTc2d J162624.0-241613
# Querying Vizier, ID:  SSTc2d J162625.4-242301
# Querying Vizier, ID:  SSTc2d J162625.6-242428
# Querying Vizier, ID:  SSTc2d J162625.9-242340
# Querying Vizier, ID:  SSTc2d J162626.4-242430
# Querying Vizier, ID:  SSTc2d J162627.5-244153
# Querying Vizier, ID:  SSTc2d J162627.7-242641
# Querying Vizier, ID:  SSTc2d J162632.9-240016
# Querying Vizier, ID:  SSTc2d J162636.8-241551
# Querying Vizier, ID:  SSTc2d J162637.7-243903
# Querying Vizier, ID:  SSTc2d J162640.4-242714
# Querying Vizier, ID:  SSTc2d J162640.8-243050
# Querying Vizier, ID:  SSTc2d J162641.2-244017
# Querying Vizier, ID:  SSTc2d J162642.1-243102
# Querying Vizier, ID:  SSTc2d J162642.8-242029
# Querying Vizier, ID:  SSTc2d J162644.1-243448
# Querying Vizier, ID:  SSTc2d J162645.0-242307
# Querying Vizier, ID:  SSTc2d J162646.4-241159
# Querying Vizier, ID:  SSTc2d J162648.4-242838
# Querying Vizier, ID:  SSTc2d J162648.6-235634
# Querying Vizier, ID:  SSTc2d J162648.9-243825
# Querying Vizier, ID:  SSTc2d J162651.9-243039
# Querying Vizier, ID:  SSTc2d J162653.4-243236
# Querying Vizier, ID:  SSTc2d J162654.2-242437
# Querying Vizier, ID:  SSTc2d J162654.4-242620
# Querying Vizier, ID:  SSTc2d J162654.7-242702
# Querying Vizier, ID:  SSTc2d J162656.4-243301
# Querying Vizier, ID:  SSTc2d J162656.7-241351
# Querying Vizier, ID:  SSTc2d J162657.3-243538
# Querying Vizier, ID:  SSTc2d J162658.2-243740
# Querying Vizier, ID:  SSTc2d J162658.3-242129
# Querying Vizier, ID:  SSTc2d J162658.4-244531
# Querying Vizier, ID:  SSTc2d J162658.6-241834
# Querying Vizier, ID:  SSTc2d J162658.6-242455
# Querying Vizier, ID:  SSTc2d J162659.0-243556
# Querying Vizier, ID:  SSTc2d J162659.1-243503
# Querying Vizier, ID:  SSTc2d J162702.3-243727
# Querying Vizier, ID:  SSTc2d J162702.9-242614
# Querying Vizier, ID:  SSTc2d J162703.5-242005
# Querying Vizier, ID:  SSTc2d J162704.1-242829
# Querying Vizier, ID:  SSTc2d J162704.5-242715
# Querying Vizier, ID:  SSTc2d J162705.2-243629
# Querying Vizier, ID:  SSTc2d J162705.6-244013
# Querying Vizier, ID:  SSTc2d J162705.9-242618
# Querying Vizier, ID:  SSTc2d J162705.9-242836
# Querying Vizier, ID:  SSTc2d J162706.5-244148
# Querying Vizier, ID:  SSTc2d J162706.7-243814
# Querying Vizier, ID:  SSTc2d J162709.0-241200
# Querying Vizier, ID:  SSTc2d J162709.0-243408
# Querying Vizier, ID:  SSTc2d J162709.3-244022
# Querying Vizier, ID:  SSTc2d J162709.4-243718
# Querying Vizier, ID:  SSTc2d J162711.1-244046
# Querying Vizier, ID:  SSTc2d J162711.7-243831
# Querying Vizier, ID:  SSTc2d J162712.1-243449
# Querying Vizier, ID:  SSTc2d J162713.2-244133
# Querying Vizier, ID:  SSTc2d J162713.7-241816
# Querying Vizier, ID:  SSTc2d J162713.8-244331
# Querying Vizier, ID:  SSTc2d J162714.4-242645
# Querying Vizier, ID:  SSTc2d J162715.1-245138
# Querying Vizier, ID:  SSTc2d J162715.4-242639
# Querying Vizier, ID:  SSTc2d J162715.5-243053
# Querying Vizier, ID:  SSTc2d J162715.8-242513
# Querying Vizier, ID:  SSTc2d J162715.8-243843
# Querying Vizier, ID:  SSTc2d J162716.3-243114
# Querying Vizier, ID:  SSTc2d J162717.5-242856
# Querying Vizier, ID:  SSTc2d J162717.5-240513
# Querying Vizier, ID:  SSTc2d J162718.3-243914
# Querying Vizier, ID:  SSTc2d J162718.4-242905
# Querying Vizier, ID:  SSTc2d J162719.2-242843
# Querying Vizier, ID:  SSTc2d J162721.4-244143
# Querying Vizier, ID:  SSTc2d J162721.7-242953
# Querying Vizier, ID:  SSTc2d J162721.8-242727
# Querying Vizier, ID:  SSTc2d J162722.9-244807
# Querying Vizier, ID:  SSTc2d J162724.5-244103
# Querying Vizier, ID:  SSTc2d J162724.6-242935
# Querying Vizier, ID:  SSTc2d J162726.2-241923
# Querying Vizier, ID:  SSTc2d J162726.2-244246
# Querying Vizier, ID:  SSTc2d J162726.5-242554
# Querying Vizier, ID:  SSTc2d J162726.9-244050
# Querying Vizier, ID:  SSTc2d J162727.3-243116
# Querying Vizier, ID:  SSTc2d J162727.9-243933
# Querying Vizier, ID:  SSTc2d J162728.4-242721
# Querying Vizier, ID:  SSTc2d J162729.9-243336
# Querying Vizier, ID:  SSTc2d J162730.1-242743
# Querying Vizier, ID:  SSTc2d J162730.8-242455
# Querying Vizier, ID:  SSTc2d J162730.9-242733
# Querying Vizier, ID:  SSTc2d J162732.1-242943
# Querying Vizier, ID:  SSTc2d J162732.6-243323
# Querying Vizier, ID:  SSTc2d J162732.7-244500
# Querying Vizier, ID:  SSTc2d J162732.8-243234
# Querying Vizier, ID:  SSTc2d J162733.1-244115
# Querying Vizier, ID:  SSTc2d J162736.1-240457
# Querying Vizier, ID:  SSTc2d J162736.6-235826
# Querying Vizier, ID:  SSTc2d J162737.2-244237
# Querying Vizier, ID:  SSTc2d J162737.4-241754
# Querying Vizier, ID:  SSTc2d J162738.3-243658
# Querying Vizier, ID:  SSTc2d J162738.3-235732
# Querying Vizier, ID:  SSTc2d J162738.6-243839
# Querying Vizier, ID:  SSTc2d J162738.9-244020
# Querying Vizier, ID:  SSTc2d J162739.0-235818
# Querying Vizier, ID:  SSTc2d J162739.4-243915
# Querying Vizier, ID:  SSTc2d J162739.8-244315
# Querying Vizier, ID:  SSTc2d J162740.1-242636
# Querying Vizier, ID:  SSTc2d J162740.2-242204
# Querying Vizier, ID:  SSTc2d J162741.4-243537
# Querying Vizier, ID:  SSTc2d J162741.6-244644
# Querying Vizier, ID:  SSTc2d J162741.7-244336
# Querying Vizier, ID:  SSTc2d J162741.7-244234
# Querying Vizier, ID:  SSTc2d J162742.6-243850
# Querying Vizier, ID:  SSTc2d J162743.7-244307
# Querying Vizier, ID:  SSTc2d J162745.0-240628
# Querying Vizier, ID:  SSTc2d J162745.7-244453
# Querying Vizier, ID:  SSTc2d J162746.2-243141
# Querying Vizier, ID:  SSTc2d J162747.0-244535
# Querying Vizier, ID:  SSTc2d J162748.2-244225
# Querying Vizier, ID:  SSTc2d J162749.7-242521
# Querying Vizier, ID:  SSTc2d J162751.7-243145
# Querying Vizier, ID:  SSTc2d J162755.2-242839
# Querying Vizier, ID:  SSTc2d J162755.2-240215
# Querying Vizier, ID:  SSTc2d J162755.5-242617
# Querying Vizier, ID:  SSTc2d J162758.8-243514
# Querying Vizier, ID:  SSTc2d J162802.5-235503
# Querying Vizier, ID:  SSTc2d J162804.5-243448
# Querying Vizier, ID:  SSTc2d J162804.7-245035
# Querying Vizier, ID:  SSTc2d J162804.7-243710
# Querying Vizier, ID:  SSTc2d J162808.0-235304
# Querying Vizier, ID:  SSTc2d J162812.7-241135
# Querying Vizier, ID:  SSTc2d J162813.6-243138
# Querying Vizier, ID:  SSTc2d J162813.7-243249
# Querying Vizier, ID:  SSTc2d J162816.5-243657
# Querying Vizier, ID:  SSTc2d J162816.7-240514
# Querying Vizier, ID:  SSTc2d J162817.7-241705
# Querying Vizier, ID:  SSTc2d J162821.5-242154
# Querying Vizier, ID:  SSTc2d J162821.6-243623
# Querying Vizier, ID:  SSTc2d J162821.6-244247
# Querying Vizier, ID:  SSTc2d J162823.3-242240
# Querying Vizier, ID:  SSTc2d J162832.6-242244
# Querying Vizier, ID:  SSTc2d J162845.2-242818
# Querying Vizier, ID:  SSTc2d J162848.7-242631
# Querying Vizier, ID:  SSTc2d J162854.0-244744
# Querying Vizier, ID:  SSTc2d J162856.0-233106
# Querying Vizier, ID:  SSTc2d J162856.9-243109
# Querying Vizier, ID:  SSTc2d J162857.8-244054
# Querying Vizier, ID:  SSTc2d J162903.2-242748
# Querying Vizier, ID:  SSTc2d J162908.2-241546
# Querying Vizier, ID:  SSTc2d J162923.3-241356
# Querying Vizier, ID:  SSTc2d J162935.0-243610
# Querying Vizier, ID:  SSTc2d J162944.2-244121
# Querying Vizier, ID:  SSTc2d J162948.3-233103
# Querying Vizier, ID:  SSTc2d J162954.5-245846
# Querying Vizier, ID:  SSTc2d J163002.2-242007
# Querying Vizier, ID:  SSTc2d J163019.7-240256
# Querying Vizier, ID:  SSTc2d J163020.0-233108
# Querying Vizier, ID:  SSTc2d J163023.3-245416
# Querying Vizier, ID:  SSTc2d J163026.7-235908
# Querying Vizier, ID:  SSTc2d J163033.9-242806
# Querying Vizier, ID:  SSTc2d J163041.4-241320
# Querying Vizier, ID:  SSTc2d J163053.4-242453
# Querying Vizier, ID:  SSTc2d J163102.3-240843
# Querying Vizier, ID:  SSTc2d J163105.1-240440
# Querying Vizier, ID:  SSTc2d J163115.7-243402
# Querying Vizier, ID:  SSTc2d J163129.2-240431
# Querying Vizier, ID:  SSTc2d J163130.8-242439
# Querying Vizier, ID:  SSTc2d J163131.2-242627
# Querying Vizier, ID:  SSTc2d J163133.4-242737
# Querying Vizier, ID:  SSTc2d J163133.8-240446
# Querying Vizier, ID:  SSTc2d J163134.0-240059
# Querying Vizier, ID:  SSTc2d J163134.2-240325
# Querying Vizier, ID:  SSTc2d J163135.6-240129
# Querying Vizier, ID:  SSTc2d J163136.7-240419
# Querying Vizier, ID:  SSTc2d J163143.7-245524
# Querying Vizier, ID:  SSTc2d J163144.5-240213
# Querying Vizier, ID:  SSTc2d J163145.3-244307
# Querying Vizier, ID:  SSTc2d J163145.8-243909
# Querying Vizier, ID:  SSTc2d J163148.9-245429
# Querying Vizier, ID:  SSTc2d J163152.0-245726
# Querying Vizier, ID:  SSTc2d J163152.1-245615
# Querying Vizier, ID:  SSTc2d J163152.4-245536
# Querying Vizier, ID:  SSTc2d J163153.4-245505
# Querying Vizier, ID:  SSTc2d J163154.4-250349
# Querying Vizier, ID:  SSTc2d J163154.7-250324
# Querying Vizier, ID:  SSTc2d J163159.3-245440
# Querying Vizier, ID:  SSTc2d J163200.9-245642
# Querying Vizier, ID:  SSTc2d J163205.5-250236
# Querying Vizier, ID:  SSTc2d J163211.8-244021
# Querying Vizier, ID:  SSTc2d J163221.0-243035
# Querying Vizier, ID:  SSTc2d J163221.9-244214
# Querying Vizier, ID:  SSTc2d J163222.6-242831
# Querying Vizier, ID:  SSTc2d J163227.1-244843
# Querying Vizier, ID:  SSTc2d J163227.8-252501
# Querying Vizier, ID:  SSTc2d J163301.5-240355
# Querying Vizier, ID:  SSTc2d J163346.2-242752
# Querying Vizier, ID:  SSTc2d J163355.6-244205
# Querying Vizier, ID:  SSTc2d J163519.4-241540
# Querying Vizier, ID:  SSTc2d J163603.9-242344
# Querying Vizier, ID:  SSTc2d J163744.2-242805
# Querying Vizier, ID:  SSTc2d J163759.9-242146
# Querying Vizier, ID:  SSTc2d J163945.4-240203
# Querying Vizier, ID:  SSTc2d J163952.9-241931
# Querying Vizier, ID:  SSTc2d J164424.2-240124
# Querying Vizier, ID:  SSTc2d J164428.8-241224
# Querying Vizier, ID:  SSTc2d J164429.3-241555
# Querying Vizier, ID:  SSTc2d J164526.6-240305
# Querying Vizier, ID:  SSTc2d J164535.4-241422
# Input Targets in 2MASS Catalogue:        292
# Missing 2MASS targets:                    10

# %%
# Review of ALL Catalogues VS 2MASS ======
cats_inp = [cat_wilking, cat_erickson_1, cat_erickson_2, cat_erickson_3, cat_dunham]
cats_out = iter([cat_wilking_tmasss, cat_erickson_1_tmasss, cat_erickson_2_tmasss, cat_erickson_3_tmasss, cat_dunham_tmasss])

for cat_inp in cats_inp:
    samp_ini.check_2mass(cat_inp, next(cats_out))
# Out:
# Input Targets in 2MASS Catalogue:        314
# Missing 2MASS targets:                     0
#
# Input Targets in 2MASS Catalogue:         74
# Missing 2MASS targets:                     1
#
# Input Targets in 2MASS Catalogue:         44
# Missing 2MASS targets:                     0
#
# Input Targets in 2MASS Catalogue:         17
# Missing 2MASS targets:                     0
#
# Input Targets in 2MASS Catalogue:        292
# Missing 2MASS targets:                    10
